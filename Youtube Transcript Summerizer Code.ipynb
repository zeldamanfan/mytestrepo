# %%
# In this program we will read the transcript of a youtube video and summarize it
# Where the transcript is longer than 10 minutes, we will split it into 10 minute chunks
# !pip install openai youtube_transcript_api
# import setcreds
import openai
import sys
from youtube_transcript_api import YouTubeTranscriptApi
openai.api_key = "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"

diagnostics = 0
include_mentions = 0

def get_video_id_from_video_id_or_url(video_id_or_url):
    # a youtube video id is 11 characters long
    # if the video id is longer than that, then it's a url
    if len(video_id_or_url) > 11:
        # it's a url
        # the video id is the last 11 characters
        return video_id_or_url[-11:]
    else:
        # it's a video id
        return video_id_or_url

def get_chunks_from_youtube(video_id):
    # this function will get the transcript of a youtube video
    # and return it as an array of chunks
    # where each chunk is an array of lines

    # first get the transcript
    transcript = YouTubeTranscriptApi.get_transcript(video_id)

    chunks = []

    start_timestamp = 0.0
    current_timestamp_mins = 0.0

    current_chunk = []

    for entry in transcript:
        current_timestamp_mins = entry['start'] / 60.0

        # if the current timestamp is more than 10 minutes after the start timestamp
        # then we have a chunk
        if current_timestamp_mins - start_timestamp > 10:
            # add the current chunk to the list of chunks
            chunks.append(current_chunk)
            # reset the start timestamp
            start_timestamp = current_timestamp_mins
            # reset the current chunk
            current_chunk = []

        # add the line to the current chunk
        current_chunk.append(entry['text'])

    # add the last chunk
    if len(current_chunk) > 0:
        chunks.append(current_chunk)

    print(f"Found {len(chunks)} chunks")

    return chunks

def summarize_chunk(index, chunk):
    chunk_str = "\n".join(chunk)
    prompt = f"""The following is a section of the transcript of a youtube video. It is section #{index+1}:
    {chunk_str}
    Summarize this section of the transcript."""

    if diagnostics:
        # print each line of the prompt with a leading # so we can see it in the output
        for line in prompt.split('\n'):
            print(f"# {line}")

    completion = openai.Completion.create(
        engine="text-davinci-003", 
        max_tokens=500, 
        temperature=0.2,
        prompt=prompt,
        frequency_penalty=0
    )

    msg = completion.choices[0].text

    if diagnostics:
        print(f"# Response: {msg}")

    return msg

def summarize_the_summaries(summaries):

    summaries_str = ""
    for index, summary in enumerate(summaries):
        summaries_str += f"Summary of chunk {index+1}:\n{summary}\n\n"

    prompt = f"""The following are summaries of a youtube video in 10 minute chunks:"
    {summaries_str}
    Summarize the summaries."""

    if diagnostics:
        # print each line of the prompt with a leading # so we can see it in the output
        for line in prompt.split('\n'):
            print(f"# {line}")

    completion = openai.Completion.create(
        engine="text-davinci-003", 
        max_tokens=500, 
        temperature=0.2,
        prompt=prompt,
        frequency_penalty=0
    )

    msg = completion.choices[0].text

    if diagnostics:
        print(f"# Response: {msg}")

    return msg

def main():
    # Get the transcript of the video
    if len(sys.argv) < 2:
        print("Usage: python3 sumvid.py <video id or url>")
        sys.exit(1)

    # transcript_file_name = sys.argv[1]
    video_id_or_url = "https://www.youtube.com/watch?v=59x-UsjbDuo"

    # if the video id or url is a url, extract the video id
    video_id = get_video_id_from_video_id_or_url(video_id_or_url)

    if len(sys.argv) > 2:
        for arg in sys.argv[2:]:
            if arg == "--diagnostics":
                global diagnostics
                diagnostics = True

            if arg == "--mentions":
                global include_mentions
                include_mentions = True

    # chunks = get_chunks(transcript_file_name)
    chunks = get_chunks_from_youtube(video_id)

    if len(chunks) == 0:
        print("No chunks found")
    elif len(chunks) == 1:
        summary = summarize_chunk(0, chunks[0])
        print(f"\nSummary: {summary}")

    else:
        # Now we have the chunks, we can summarize each one
        summaries = []
        for index, chunk in enumerate(chunks):
            summary = summarize_chunk(index, chunk)
            summaries.append(summary)
            print(f"\nSummary of chunk {index+1}: {summary}")

        # Now we have the summaries, we can summarize the summaries
        summary_of_summaries = summarize_the_summaries(summaries)

        print(f"\nSummary of summaries: {summary_of_summaries}")

if __name__ == "__main__":
    main()
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: openai in /opt/conda/lib/python3.7/site-packages (0.26.1)
# Requirement already satisfied: youtube_transcript_api in /opt/conda/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from openai) (4.4.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from openai) (4.32.2)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.7/site-packages (from openai) (2.28.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.7/site-packages (from openai) (3.8.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->openai) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->openai) (1.25.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->openai) (2019.11.28)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (19.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.7/site-packages (from aiohttp->openai) (1.3.1)
# Found 6 chunks
#
# Summary of chunk 1:
#
# In this section, Noah is at the Carson house to watch it while the owner is away. He is given instructions by his dad to keep the doors locked and not to open them for anyone. He explores the house and finds a fake rock in the backyard with a key. He also meets a dog and talks to it. He has a dream about his dad and then realizes he has to feed the dog. He then notices a strange smell coming from the bedroom and hears breathing. He is overwhelmed by the size of the house and the number of places things can hide.
#
# Summary of chunk 2:
#
# In this section of the transcript, the speaker is exploring a dark basement and trying to find food for a dog named Zeke. They find a tin of beans and a TV, and watch a cooking show. They then try to figure out the security system before leaving to get groceries. They remind themselves to remain calm in conversations and end the section by saying they are happy.
#
# Summary of chunk 3:
#
# In this section of the transcript, the protagonist is shopping for groceries and trying to find items such as mustard, eggs, and peas. They encounter an old lady who needs help finding mustard, and the protagonist helps her. They then find a box of cereal in their basket and pay for their groceries before leaving.
#
# Summary of chunk 4:
#
# In this section, the speaker is at a grocery store and has just purchased a box of cereal. They then encounter a stranger who asks them to search up "Roy Carson divorce" on the internet. The speaker then discovers that Roy Carson, the co-founder of BN media, is receiving death threats from the fans of his ex-wife. After this, the speaker is then confronted by someone at the door who turns out to be a pizza delivery man. The speaker then decides to wait inside until the rain stops and is then startled by a noise. They investigate and find that it is Zeke, who is carrying a duffel bag. The speaker then eats the pizza and is about to leave when they hear a noise outside and become concerned that it might be one of Roy Carson's fans. They arm themselves with a gun and investigate, but it turns out to be a stranger with flowers. The speaker then finishes their pizza and goes to check the cameras. They find Zeke and then the section ends.
#
# Summary of chunk 5:
#
# In this section, the protagonist is trying to figure out who is in their house after the power went out. They search the house and find that someone has been snooping around. They try to contact Andy to get Turner's contact information in order to confront him, but they end up deciding to keep an eye on the security monitor instead. They consider calling the cops, but they are so engrossed in their own thoughts that the idea never enters their head. They then find something sketchy and freeze in horror, unsure of what to do.
#
# Summary of chunk 6:
#
# In this section, the speaker recounts their experience playing a video game in which they had to hide from a woman who was trying to break into their house. They describe the fear they felt as the woman was knocking on the door and how they had to leave the house and run away. They then explain that the woman was an ex-girlfriend who was under the influence of drugs and alcohol and had been arrested. The speaker expresses their appreciation for the game and how it tapped into their primal fear of someone breaking into their home.
#
# Summary of summaries:
#
# The protagonist is exploring a house while the owner is away and finds a key in a fake rock. They encounter a dog and watch a cooking show in the basement. They go grocery shopping and help an old lady find mustard. They are then asked to search for information on Roy Carson's divorce and are confronted by a pizza delivery man. They arm themselves with a gun when they hear a noise outside and find it is a stranger with flowers. They then investigate the house after the power goes out and find someone has been snooping around. Finally, they recount their experience playing a video game in which they had to hide from an ex-girlfriend who was under the influence of drugs and alcohol.
